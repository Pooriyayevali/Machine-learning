# %% [markdown]
# <a href="https://colab.research.google.com/github/Pooriyayevali/Machine-learning/blob/main/APD_t1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# %%
apd = pd.read_csv("/Daegu_Real_Estate_data.csv", sep = ',' , header=0)
apd.describe()
apd.head()
correlation = apd.corr()
plt.imshow(correlation)
plt.show()

# %%
sb.heatmap(correlation, vmax = 1 , vmin = -1)
# apd.plotting.scatter_matrix()

# %%
# data = apd.to_numpy()
Y = apd['SalePrice'].to_numpy().reshape((-1,1))
apd.drop(['SalePrice'], inplace=True , axis=1)
x = apd.to_numpy()
